# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\subha\\Downloads\\Building_Permits.csv")
df.head()
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_13204\147152234.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("C:\\Users\\subha\\Downloads\\Building_Permits.csv")
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# ...

# %%
df.isnull().sum()
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
totalCells=np.product(df.shape)

# %%
df.shape
# Out:
# (198900, 43)

# %%
totalCells
# Out:
# 8552700

# %%
missingCount=df.isnull().sum()

# %%
missingCount
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
totalMissing=missingCount.sum()

# %%
totalMissing
# Out:
# 2245941

# %%
print("this dataset contains",round((totalMissing/totalCells)*100,2),"%","missing values.")
# Out:
# this dataset contains 26.26 % missing values.

# %%
missingCount[['Street Number Suffix','Zipcode']]
# Out:
# Street Number Suffix    196684
# Zipcode                   1716
# dtype: int64

# %%
print("Percent missing data in Street Number Suffix column=",(round((missingCount['Street Number Suffix']/df.shape[0]*100),2)))
# Out:
# Percent missing data in Street Number Suffix column= 98.89

# %%
print("Percent missing data in Zipcode column=",(round((missingCount['Zipcode']/df.shape[0]*100),2)))
# Out:
# Percent missing data in Zipcode column= 0.86

# %%
sfPermitsCleanCols=df.dropna(axis=1)

# %%
sfPermitsCleanCols.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# 4           11/28/2016  0342  001            950      Market         issued
#
#   Current Status Date  Filed Date      Record ID
# 0          12/21/2017  05/06/2015  1380611233945
# ...

# %%
print("column in origanal datset : %d\n" %df.shape[1])
# Out:
# column in origanal datset : 43

# %%
print("Column with na's dropped: %d"%sfPermitsCleanCols.shape[1])
# Out:
# Column with na's dropped: 12

# %%
df.shape
# Out:
# (198900, 43)

# %%
sfPermitsCleanCols.shape
# Out:
# (198900, 12)

# %%
sfPermitsCleanCols.isnull().sum()
# Out:
# Permit Number             0
# Permit Type               0
# Permit Type Definition    0
# Permit Creation Date      0
# Block                     0
# Lot                       0
# Street Number             0
# Street Name               0
# Current Status            0
# Current Status Date       0
# Filed Date                0
# Record ID                 0
# dtype: int64

# %%
imputeSfPermits=df.fillna(method='ffill',axis=0).fillna("0")

# %%
imputeSfPermits_new=df.fillna(method='ffill',axis=1).fillna("0")

# %%
imputeSfPermits
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %%
imputeSfPermits_new
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %%
imputeSfPermits.shape
# Out:
# (198900, 43)

# %%
imputeSfPermits_new.shape
# Out:
# (198900, 43)
